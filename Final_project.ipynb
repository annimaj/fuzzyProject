# %%
import pandas as pd
import numpy as np
hp_train = pd.read_csv("train.csv")
pd.set_option("display.max.columns", None)
pd.set_option("display.precision", 2)
hp_train.head(5)
# Out:
#    patient_id patient_race  payer_type patient_state  patient_zip3   Region  \
# 0      268700          NaN  COMMERCIAL            AR           724    South
# 1      484983        White         NaN            IL           629  Midwest
# 2      277055          NaN  COMMERCIAL            CA           925     West
# 3      320055     Hispanic    MEDICAID            CA           900     West
# 4      190386          NaN  COMMERCIAL            CA           934     West
#
#              Division  patient_age patient_gender    bmi  \
# 0  West South Central           39              F    NaN
# 1  East North Central           55              F  35.36
# 2             Pacific           59              F    NaN
# 3             Pacific           59              F    NaN
# 4             Pacific           71              F    NaN
#
#   breast_cancer_diagnosis_code  \
# 0                       C50912
# 1                       C50412
# 2                         1749
# 3                       C50911
# ...

# %%
#Making a hard copy of the original file.

hp_train_copy = hp_train.copy()
hp_train_copy.head(5)
# Out:
#    patient_id patient_race  payer_type patient_state  patient_zip3   Region  \
# 0      268700          NaN  COMMERCIAL            AR           724    South
# 1      484983        White         NaN            IL           629  Midwest
# 2      277055          NaN  COMMERCIAL            CA           925     West
# 3      320055     Hispanic    MEDICAID            CA           900     West
# 4      190386          NaN  COMMERCIAL            CA           934     West
#
#              Division  patient_age patient_gender    bmi  \
# 0  West South Central           39              F    NaN
# 1  East North Central           55              F  35.36
# 2             Pacific           59              F    NaN
# 3             Pacific           59              F    NaN
# 4             Pacific           71              F    NaN
#
#   breast_cancer_diagnosis_code  \
# 0                       C50912
# 1                       C50412
# 2                         1749
# 3                       C50911
# ...

# %%
#Checking which columns include NA values.

hp_train_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13173 entries, 0 to 13172
# Columns: 152 entries, patient_id to metastatic_diagnosis_period
# dtypes: float64(137), int64(4), object(11)
# memory usage: 15.3+ MB

# %%
#Checking which columns include NA values.

hp_train_copy.columns[hp_train_copy.isna().any()].tolist()
# Out:
# ['patient_race',
#  'payer_type',
#  'bmi',
#  'metastatic_first_novel_treatment',
#  'metastatic_first_novel_treatment_type',
#  'family_size',
#  'family_dual_income',
#  'income_household_median',
#  'income_household_under_5',
#  'income_household_5_to_10',
#  'income_household_10_to_15',
#  'income_household_15_to_20',
#  'income_household_20_to_25',
#  'income_household_25_to_35',
#  'income_household_35_to_50',
#  'income_household_50_to_75',
#  'income_household_75_to_100',
#  'income_household_100_to_150',
#  'income_household_150_over',
#  'income_household_six_figure',
#  'home_ownership',
#  'home_value',
#  'rent_median',
#  'rent_burden',
#  'self_employed',
#  'farmer',
#  'poverty',
#  'limited_english',
#  'Average of Jan-13',
#  'Average of Feb-13',
#  'Average of May-13',
#  'Average of Jun-13',
#  'Average of Aug-13',
#  'Average of Sep-13',
#  'Average of Oct-13',
#  'Average of Nov-13',
#  'Average of Dec-13',
#  'Average of Jan-14',
#  'Average of Feb-14',
# ...

# %%
#Replacing NA values with 0.

hp_train_copy["patient_race"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["payer_type"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["bmi"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["metastatic_first_novel_treatment"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["metastatic_first_novel_treatment_type"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["family_size"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["family_dual_income"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["income_household_median"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["income_household_under_5"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["income_household_5_to_10"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["income_household_10_to_15"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["income_household_15_to_20"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["income_household_20_to_25"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["income_household_25_to_35"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["income_household_35_to_50"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["income_household_50_to_75"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["income_household_75_to_100"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["income_household_100_to_150"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["income_household_150_over"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["income_household_six_figure"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["home_ownership"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["home_value"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["rent_median"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["rent_burden"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["self_employed"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["farmer"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["poverty"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["limited_english"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Jan-13"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Feb-13"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of May-13"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Jun-13"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Aug-13"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Sep-13"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Oct-13"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Nov-13"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Dec-13"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Jan-14"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Feb-14"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Mar-14"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Apr-14"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Jun-14"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Nov-14"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Jan-15"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Feb-15"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Mar-15"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Apr-15"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Aug-15"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Oct-15"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Nov-15"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Dec-15"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Jan-16"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Feb-16"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of May-16"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Jul-16"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Nov-16"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Dec-16"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Jan-17"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Jun-17"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Jul-17"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Sep-17"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Oct-17"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Nov-17"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Feb-18"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Mar-18"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Jun-18"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Jul-18"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Aug-18"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Sep-18"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Oct-18"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Nov-18"].fillna(
    value=0,
    inplace=True
)
hp_train_copy["Average of Dec-18"].fillna(
    value=0,
    inplace=True
)

hp_train_copy.columns[hp_train_copy.isna().any()].tolist()
# Out:
# []

# %%
#Identifying all columns with string values.

hp_train_copy.dtypes[hp_train_copy.dtypes == 'object']
# Out:
# patient_race                             object
# payer_type                               object
# patient_state                            object
# Region                                   object
# Division                                 object
# patient_gender                           object
# breast_cancer_diagnosis_code             object
# breast_cancer_diagnosis_desc             object
# metastatic_cancer_diagnosis_code         object
# metastatic_first_novel_treatment         object
# metastatic_first_novel_treatment_type    object
# dtype: object

# %%
#One-hot encoding for columns that include String values.

hp_train_copy = pd.get_dummies(hp_train_copy, columns = ["patient_race", "payer_type", "patient_state", "Region", "Division", "patient_gender", "breast_cancer_diagnosis_code", "breast_cancer_diagnosis_desc", "metastatic_cancer_diagnosis_code", "metastatic_first_novel_treatment", "metastatic_first_novel_treatment_type"])

# %%
#Just checking my one-hot encoding results...

hp_train_copy.head(2)
# Out:
#    patient_id  patient_zip3  patient_age    bmi  population  density  \
# 0      268700           724           39   0.00     3924.87    82.63
# 1      484983           629           55  35.36     2745.39    51.79
#
#    age_median  age_under_10  age_10_to_19  age_20s  age_30s  age_40s  age_50s  \
# 0       42.58         11.61         13.03    10.87    11.80    12.29    13.22
# 1       43.54         11.22         12.19    11.45    11.01    11.35    14.39
#
#    age_60s  age_70s  age_over_80   male  female  married  divorced  \
# 0    13.47    10.07         3.64  51.43   48.57    51.05     16.72
# 1    14.15     9.17         5.05  49.32   50.68    49.48     15.42
#
#    never_married  widowed  family_size  family_dual_income  \
# 0          23.57     8.66         3.01               43.99
# 1          26.93     8.17         3.17               41.41
#
#    income_household_median  income_household_under_5  \
# 0                 44483.35                      2.21
# ...

# %%
#Dropping the "patient_id" column because I don´t want it to be included in any association rules.

hp_train_copy = hp_train_copy.drop(["patient_id"], axis=1)

# %%
#Just checking...

hp_train_copy.head(2)
# Out:
#    patient_zip3  patient_age    bmi  population  density  age_median  \
# 0           724           39   0.00     3924.87    82.63       42.58
# 1           629           55  35.36     2745.39    51.79       43.54
#
#    age_under_10  age_10_to_19  age_20s  age_30s  age_40s  age_50s  age_60s  \
# 0         11.61         13.03    10.87    11.80    12.29    13.22    13.47
# 1         11.22         12.19    11.45    11.01    11.35    14.39    14.15
#
#    age_70s  age_over_80   male  female  married  divorced  never_married  \
# 0    10.07         3.64  51.43   48.57    51.05     16.72          23.57
# 1     9.17         5.05  49.32   50.68    49.48     15.42          26.93
#
#    widowed  family_size  family_dual_income  income_household_median  \
# 0     8.66         3.01               43.99                 44483.35
# 1     8.17         3.17               41.41                 51796.79
#
#    income_household_under_5  income_household_5_to_10  \
# ...

# %%
#Trying to find important Features with Scikit-learn. 

from sklearn.model_selection import train_test_split

X = hp_train_copy[['patient_zip3', 'patient_age', 'bmi', 'population', 'density', 'age_median', 'age_under_10', 'age_10_to_19', 'age_20s', 'age_30s', 'age_40s', 'age_50s', 'age_60s', 'age_70s', 'age_over_80', 'male', 'female', 'married', 'divorced', 'never_married', 'widowed', 'family_size', 'family_dual_income', 'income_household_median', 'income_household_under_5', 'income_household_5_to_10', 'income_household_10_to_15', 'income_household_15_to_20', 'income_household_20_to_25', 'income_household_25_to_35', 'income_household_35_to_50', 'income_household_50_to_75', 'income_household_75_to_100', 'income_household_100_to_150', 'income_household_150_over', 'income_household_six_figure', 'income_individual_median', 'home_ownership', 'housing_units', 'home_value', 'rent_median', 'rent_burden', 'education_less_highschool', 'education_highschool', 'education_some_college', 'education_bachelors', 'education_graduate', 'education_college_or_above', 'education_stem_degree', 'labor_force_participation', 'unemployment_rate', 'self_employed', 'farmer', 'race_white', 'race_black', 'race_asian', 'race_native', 'race_pacific', 'race_other', 'race_multiple', 'hispanic', 'disabled', 'poverty', 'limited_english', 'commute_time', 'health_uninsured', 'veteran', 'Average of Jan-13', 'Average of Feb-13', 'Average of Mar-13', 'Average of Apr-13', 'Average of May-13', 'Average of Jun-13', 'Average of Jul-13', 'Average of Aug-13', 'Average of Sep-13', 'Average of Oct-13', 'Average of Nov-13', 'Average of Dec-13', 'Average of Jan-14', 'Average of Feb-14', 'Average of Mar-14', 'Average of Apr-14', 'Average of May-14', 'Average of Jun-14', 'Average of Jul-14', 'Average of Aug-14', 'Average of Sep-14', 'Average of Oct-14', 'Average of Nov-14', 'Average of Dec-14', 'Average of Jan-15', 'Average of Feb-15', 'Average of Mar-15', 'Average of Apr-15', 'Average of May-15', 'Average of Jun-15', 'Average of Jul-15', 'Average of Aug-15', 'Average of Sep-15', 'Average of Oct-15', 'Average of Nov-15', 'Average of Dec-15', 'Average of Jan-16', 'Average of Feb-16', 'Average of Mar-16', 'Average of Apr-16', 'Average of May-16', 'Average of Jun-16', 'Average of Jul-16', 'Average of Jul-16', 'Average of Aug-16', 'Average of Sep-16', 'Average of Oct-16', 'Average of Nov-16', 'Average of Dec-16', 'Average of Jan-17', 'Average of Feb-17', 'Average of Mar-17', 'Average of Apr-17', 'Average of May-17', 'Average of Jun-17', 'Average of Aug-17', 'Average of Sep-17', 'Average of Oct-17', 'Average of Nov-17', 'Average of Dec-17', 'Average of Jan-18', 'Average of Feb-18', 'Average of Mar-18', 'Average of Apr-18', 'Average of May-18', 'Average of Jun-18', 'Average of Jul-18', 'Average of Aug-18', 'Average of Sep-18', 'Average of Oct-18', 'Average of Nov-18', 'Average of Dec-18', 'patient_race_0', 'patient_race_Asian', 'patient_race_Black', 'patient_race_Hispanic', 'patient_race_Other', 'patient_race_White', 'payer_type_0', 'payer_type_COMMERCIAL', 'payer_type_MEDICAID', 'payer_type_MEDICARE ADVANTAGE', 'patient_state_AK', 'patient_state_AL', 'patient_state_AR', 'patient_state_AZ', 'patient_state_CA', 'patient_state_CO', 'patient_state_DC', 'patient_state_DE', 'patient_state_FL', 'patient_state_GA', 'patient_state_HI', 'patient_state_IA', 'patient_state_ID', 'patient_state_IL', 'patient_state_IN', 'patient_state_KS', 'patient_state_KY', 'patient_state_LA', 'patient_state_MD', 'patient_state_MI', 'patient_state_MN', 'patient_state_MO', 'patient_state_MS', 'patient_state_MT', 'patient_state_NC', 'patient_state_ND', 'patient_state_NE', 'patient_state_NM', 'patient_state_NV', 'patient_state_NY', 'patient_state_OH', 'patient_state_OK', 'patient_state_OR', 'patient_state_PA', 'patient_state_SC', 'patient_state_SD', 'patient_state_TN', 'patient_state_TX', 'patient_state_UT', 'patient_state_VA', 'patient_state_WA', 'patient_state_WI', 'patient_state_WV', 'patient_state_WY', 'Region_Midwest', 'Region_Northeast', 'Region_South', 'Region_West', 'Division_East North Central', 'Division_East South Central', 'Division_Middle Atlantic', 'Division_Mountain', 'Division_Pacific', 'Division_South Atlantic', 'Division_West North Central', 'Division_West South Central', 'patient_gender_F', 'breast_cancer_diagnosis_code_1741', 'breast_cancer_diagnosis_code_1742', 'breast_cancer_diagnosis_code_1743', 'breast_cancer_diagnosis_code_1744', 'breast_cancer_diagnosis_code_1745', 'breast_cancer_diagnosis_code_1746', 'breast_cancer_diagnosis_code_1748', 'breast_cancer_diagnosis_code_1749', 'breast_cancer_diagnosis_code_19881',  'breast_cancer_diagnosis_code_C5001', 'breast_cancer_diagnosis_code_C50011', 'breast_cancer_diagnosis_code_C50012', 'breast_cancer_diagnosis_code_C50019', 'breast_cancer_diagnosis_code_C5011', 'breast_cancer_diagnosis_code_C50111', 'breast_cancer_diagnosis_code_C50112', 'breast_cancer_diagnosis_code_C50119', 'breast_cancer_diagnosis_code_C50122', 'breast_cancer_diagnosis_code_C50212', 'breast_cancer_diagnosis_code_C50219', 'breast_cancer_diagnosis_code_C50221', 'breast_cancer_diagnosis_code_C5031', 'breast_cancer_diagnosis_code_C50311', 'breast_cancer_diagnosis_code_C50312', 'breast_cancer_diagnosis_code_C50319', 'breast_cancer_diagnosis_code_C5041', 'breast_cancer_diagnosis_code_C50411', 'breast_cancer_diagnosis_code_C50412', 'breast_cancer_diagnosis_code_C50419', 'breast_cancer_diagnosis_code_C50421', 'breast_cancer_diagnosis_code_C50511', 'breast_cancer_diagnosis_code_C50512', 'breast_cancer_diagnosis_code_C50519', 'breast_cancer_diagnosis_code_C50611', 'breast_cancer_diagnosis_code_C50612', 'breast_cancer_diagnosis_code_C50619', 'breast_cancer_diagnosis_code_C5081', 'breast_cancer_diagnosis_code_C50811', 'breast_cancer_diagnosis_code_C50812', 'breast_cancer_diagnosis_code_C50819', 'breast_cancer_diagnosis_code_C509', 'breast_cancer_diagnosis_code_C5091', 'breast_cancer_diagnosis_code_C50911', 'breast_cancer_diagnosis_code_C50911', 'breast_cancer_diagnosis_code_C50111', 'breast_cancer_diagnosis_code_C50112', 'breast_cancer_diagnosis_code_C50119', 'breast_cancer_diagnosis_code_C50211', 'breast_cancer_diagnosis_code_C50212', 'breast_cancer_diagnosis_code_C50219', 'breast_cancer_diagnosis_code_C50311', 'breast_cancer_diagnosis_code_C50312', 'breast_cancer_diagnosis_code_C50319', 'breast_cancer_diagnosis_code_C5041', 'breast_cancer_diagnosis_code_C50411', 'breast_cancer_diagnosis_code_C50412', 'breast_cancer_diagnosis_code_C50419', 'breast_cancer_diagnosis_code_C50421',  'breast_cancer_diagnosis_code_C50511', 'breast_cancer_diagnosis_code_C50512', 'breast_cancer_diagnosis_code_C50519', 'breast_cancer_diagnosis_code_C50611', 'breast_cancer_diagnosis_code_C50612', 'breast_cancer_diagnosis_code_C50619', 'breast_cancer_diagnosis_code_C5081', 'breast_cancer_diagnosis_code_C50811', 'breast_cancer_diagnosis_code_C50812', 'breast_cancer_diagnosis_code_C50819', 'breast_cancer_diagnosis_code_C5091', 'breast_cancer_diagnosis_code_C50911', 'breast_cancer_diagnosis_code_C50912', 'breast_cancer_diagnosis_code_C50919', 'breast_cancer_diagnosis_code_C50922', 'breast_cancer_diagnosis_desc_Malig neoplasm of lower-inner quadrant of left female breast', 'breast_cancer_diagnosis_desc_Malig neoplasm of lower-inner quadrant of unsp female breast', 'breast_cancer_diagnosis_desc_Malig neoplasm of lower-outer quadrant of left female breast', 'breast_cancer_diagnosis_desc_Malig neoplasm of lower-outer quadrant of unsp female breast', 'breast_cancer_diagnosis_desc_Malig neoplasm of upper-inner quadrant of left female breast', 'breast_cancer_diagnosis_desc_Malig neoplasm of upper-inner quadrant of right male breast', 'breast_cancer_diagnosis_desc_Malig neoplasm of upper-inner quadrant of unsp female breast', 'breast_cancer_diagnosis_desc_Malig neoplasm of upper-outer quadrant of left female breast', 'breast_cancer_diagnosis_desc_Malig neoplasm of upper-outer quadrant of right male breast', 'breast_cancer_diagnosis_desc_Malig neoplasm of upper-outer quadrant of unsp female breast', 'breast_cancer_diagnosis_desc_Malig neoplm of lower-inner quadrant of right female breast', 'breast_cancer_diagnosis_desc_Malig neoplm of lower-outer quadrant of right female breast', 'breast_cancer_diagnosis_desc_Malig neoplm of upper-inner quadrant of right female breast', 'breast_cancer_diagnosis_desc_Malig neoplm of upper-outer quadrant of right female breast', 'breast_cancer_diagnosis_desc_Malignant neoplasm of axillary tail of female breast', 'breast_cancer_diagnosis_desc_Malignant neoplasm of axillary tail of left female breast', 'breast_cancer_diagnosis_desc_Malignant neoplasm of axillary tail of right female breast',  'breast_cancer_diagnosis_desc_Malignant neoplasm of axillary tail of unsp female breast', 'breast_cancer_diagnosis_desc_Malignant neoplasm of breast (female), unspecified', 'breast_cancer_diagnosis_desc_Malignant neoplasm of breast of unspecified site', 'breast_cancer_diagnosis_desc_Malignant neoplasm of breast of unspecified site, female', 'breast_cancer_diagnosis_desc_Malignant neoplasm of central portion of breast, female', 'breast_cancer_diagnosis_desc_Malignant neoplasm of central portion of female breast', 'breast_cancer_diagnosis_desc_Malignant neoplasm of central portion of left female breast', 'breast_cancer_diagnosis_desc_Malignant neoplasm of central portion of left male breast', 'breast_cancer_diagnosis_desc_Malignant neoplasm of central portion of right female breast', 'breast_cancer_diagnosis_desc_Malignant neoplasm of central portion of unsp female breast',  'breast_cancer_diagnosis_desc_Malignant neoplasm of lower-inner quadrant of breast, female', 'breast_cancer_diagnosis_desc_Malignant neoplasm of lower-inner quadrant of female breast', 'metastatic_first_novel_treatment_type_Antineoplastics', 'metastatic_first_novel_treatment_type_0', 'metastatic_first_novel_treatment_PEMBROLIZUMAB', 'metastatic_first_novel_treatment_OLAPARIB']]  # Features
y = hp_train_copy['metastatic_diagnosis_period']  # Label

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.01) # 99% training and 1% test. Unfortunately 100% training was not allowed.

# %%
from sklearn.ensemble import RandomForestClassifier

#Creating a Gaussian Classifier.

clf=RandomForestClassifier(n_estimators=100)

#Training the model using the training sets y_pred=clf.predict(X_test).

clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0,
            min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)
# Out:
# RandomForestClassifier(max_features='auto', n_jobs=1)

# %%
feature_imp = pd.Series(clf.feature_importances_,index=X.columns).sort_values(ascending=False)
feature_imp
# Out:
# patient_age              1.70e-01
# bmi                      6.66e-02
# patient_race_0           3.16e-02
# patient_race_White       2.73e-02
# payer_type_COMMERCIAL    2.55e-02
#                            ...
# patient_state_DC         7.05e-06
# patient_state_ND         2.26e-06
# patient_state_AK         1.61e-06
# patient_gender_F         0.00e+00
# patient_state_WY         0.00e+00
# Length: 312, dtype: float64

# %%
print(feature_imp.head(25))
# Out:
# patient_age                                                                                  1.70e-01
# bmi                                                                                          6.66e-02
# patient_race_0                                                                               3.16e-02
# patient_race_White                                                                           2.73e-02
# payer_type_COMMERCIAL                                                                        2.55e-02
# payer_type_MEDICARE ADVANTAGE                                                                2.04e-02
# payer_type_MEDICAID                                                                          1.85e-02
# breast_cancer_diagnosis_code_C50912                                                          1.82e-02
# breast_cancer_diagnosis_code_C50919                                                          1.36e-02
# ...

# %%
import matplotlib.pyplot as plt

feature_imp.nlargest(10).plot(kind='barh', color='orange')
plt.tight_layout()
plt.savefig('features.pdf')

# %%
#Replacing NA values with 0 in the training set.

hp_train["patient_race"].fillna(
    value=0,
    inplace=True
)
hp_train["payer_type"].fillna(
    value=0,
    inplace=True
)
hp_train["bmi"].fillna(
    value=0,
    inplace=True
)
hp_train["metastatic_first_novel_treatment"].fillna(
    value=0,
    inplace=True
)
hp_train["metastatic_first_novel_treatment_type"].fillna(
    value=0,
    inplace=True
)
hp_train["family_size"].fillna(
    value=0,
    inplace=True
)
hp_train["family_dual_income"].fillna(
    value=0,
    inplace=True
)
hp_train["income_household_median"].fillna(
    value=0,
    inplace=True
)
hp_train["income_household_under_5"].fillna(
    value=0,
    inplace=True
)
hp_train["income_household_5_to_10"].fillna(
    value=0,
    inplace=True
)
hp_train["income_household_10_to_15"].fillna(
    value=0,
    inplace=True
)
hp_train["income_household_15_to_20"].fillna(
    value=0,
    inplace=True
)
hp_train["income_household_20_to_25"].fillna(
    value=0,
    inplace=True
)
hp_train["income_household_25_to_35"].fillna(
    value=0,
    inplace=True
)
hp_train["income_household_35_to_50"].fillna(
    value=0,
    inplace=True
)
hp_train["income_household_50_to_75"].fillna(
    value=0,
    inplace=True
)
hp_train["income_household_75_to_100"].fillna(
    value=0,
    inplace=True
)
hp_train["income_household_100_to_150"].fillna(
    value=0,
    inplace=True
)
hp_train["income_household_150_over"].fillna(
    value=0,
    inplace=True
)
hp_train["income_household_six_figure"].fillna(
    value=0,
    inplace=True
)
hp_train["home_ownership"].fillna(
    value=0,
    inplace=True
)
hp_train["home_value"].fillna(
    value=0,
    inplace=True
)
hp_train["rent_median"].fillna(
    value=0,
    inplace=True
)
hp_train["rent_burden"].fillna(
    value=0,
    inplace=True
)
hp_train["self_employed"].fillna(
    value=0,
    inplace=True
)
hp_train["farmer"].fillna(
    value=0,
    inplace=True
)
hp_train["poverty"].fillna(
    value=0,
    inplace=True
)
hp_train["limited_english"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Jan-13"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Feb-13"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of May-13"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Jun-13"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Aug-13"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Sep-13"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Oct-13"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Nov-13"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Dec-13"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Jan-14"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Feb-14"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Mar-14"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Apr-14"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Jun-14"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Nov-14"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Jan-15"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Feb-15"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Mar-15"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Apr-15"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Aug-15"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Oct-15"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Nov-15"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Dec-15"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Jan-16"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Feb-16"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of May-16"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Jul-16"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Nov-16"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Dec-16"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Jan-17"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Jun-17"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Jul-17"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Sep-17"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Oct-17"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Nov-17"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Feb-18"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Mar-18"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Jun-18"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Jul-18"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Aug-18"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Sep-18"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Oct-18"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Nov-18"].fillna(
    value=0,
    inplace=True
)
hp_train["Average of Dec-18"].fillna(
    value=0,
    inplace=True
)

hp_train.columns[hp_train.isna().any()].tolist()
# Out:
# []

# %%
#One-hot encoding for columns that include String values.

hp_train = pd.get_dummies(hp_train, columns = ["patient_race", "payer_type", "patient_state", "Region", "Division", "patient_gender", "breast_cancer_diagnosis_code", "breast_cancer_diagnosis_desc", "metastatic_cancer_diagnosis_code", "metastatic_first_novel_treatment", "metastatic_first_novel_treatment_type"])

# %%
hp_train.head(2)
# Out:
#    patient_id  patient_zip3  patient_age    bmi  population  density  \
# 0      268700           724           39   0.00     3924.87    82.63
# 1      484983           629           55  35.36     2745.39    51.79
#
#    age_median  age_under_10  age_10_to_19  age_20s  age_30s  age_40s  age_50s  \
# 0       42.58         11.61         13.03    10.87    11.80    12.29    13.22
# 1       43.54         11.22         12.19    11.45    11.01    11.35    14.39
#
#    age_60s  age_70s  age_over_80   male  female  married  divorced  \
# 0    13.47    10.07         3.64  51.43   48.57    51.05     16.72
# 1    14.15     9.17         5.05  49.32   50.68    49.48     15.42
#
#    never_married  widowed  family_size  family_dual_income  \
# 0          23.57     8.66         3.01               43.99
# 1          26.93     8.17         3.17               41.41
#
#    income_household_median  income_household_under_5  \
# 0                 44483.35                      2.21
# ...

# %%
#Creating a new df with only important Features

hp_train2 = hp_train[['patient_age', 'bmi', 'patient_race_0', 'patient_race_White', 'payer_type_COMMERCIAL', 'payer_type_MEDICARE ADVANTAGE', 'payer_type_MEDICAID', 'breast_cancer_diagnosis_code_C50912', 'payer_type_0', 'breast_cancer_diagnosis_code_C50919', 'metastatic_diagnosis_period']]

# %%
hp_train2.head(2)
# Out:
#    patient_age    bmi  patient_race_0  patient_race_White  \
# 0           39   0.00            True               False
# 1           55  35.36           False                True
#
#    payer_type_COMMERCIAL  payer_type_MEDICARE ADVANTAGE  payer_type_MEDICAID  \
# 0                   True                          False                False
# 1                  False                          False                False
#
#    breast_cancer_diagnosis_code_C50912  payer_type_0  \
# 0                                 True         False
# 1                                False          True
#
#    breast_cancer_diagnosis_code_C50919  metastatic_diagnosis_period
# 0                                False                          191
# 1                                False                           33

# %%
#Importing my test file.

hp_test = pd.read_csv("test.csv")
pd.set_option("display.max.columns", None)
pd.set_option("display.precision", 2)
hp_test.head(5)
# Out:
#    patient_id patient_race  payer_type patient_state  patient_zip3 Region  \
# 0      730681          NaN  COMMERCIAL            LA           713  South
# 1      334212        Black         NaN            NC           283  South
# 2      571362          NaN  COMMERCIAL            TX           794  South
# 3      907331          NaN  COMMERCIAL            TN           373  South
# 4      208382        Asian         NaN            WA           980   West
#
#              Division  patient_age patient_gender    bmi  \
# 0  West South Central           55              F    NaN
# 1      South Atlantic           60              F  40.00
# 2  West South Central           54              F  32.33
# 3  East South Central           63              F  27.07
# 4             Pacific           62              F    NaN
#
#   breast_cancer_diagnosis_code  \
# 0                         1746
# 1                       C50912
# 2                         1742
# 3                         1748
# ...

# %%
#Replacing NA values with 0 in the test file.

hp_test["patient_race"].fillna(
    value=0,
    inplace=True
)
hp_test["payer_type"].fillna(
    value=0,
    inplace=True
)
hp_test["bmi"].fillna(
    value=0,
    inplace=True
)
hp_test["metastatic_first_novel_treatment"].fillna(
    value=0,
    inplace=True
)
hp_test["metastatic_first_novel_treatment_type"].fillna(
    value=0,
    inplace=True
)
hp_test["family_size"].fillna(
    value=0,
    inplace=True
)
hp_test["family_dual_income"].fillna(
    value=0,
    inplace=True
)
hp_test["income_household_median"].fillna(
    value=0,
    inplace=True
)
hp_test["income_household_under_5"].fillna(
    value=0,
    inplace=True
)
hp_test["income_household_5_to_10"].fillna(
    value=0,
    inplace=True
)
hp_test["income_household_10_to_15"].fillna(
    value=0,
    inplace=True
)
hp_test["income_household_15_to_20"].fillna(
    value=0,
    inplace=True
)
hp_test["income_household_20_to_25"].fillna(
    value=0,
    inplace=True
)
hp_test["income_household_25_to_35"].fillna(
    value=0,
    inplace=True
)
hp_test["income_household_35_to_50"].fillna(
    value=0,
    inplace=True
)
hp_test["income_household_50_to_75"].fillna(
    value=0,
    inplace=True
)
hp_test["income_household_75_to_100"].fillna(
    value=0,
    inplace=True
)
hp_test["income_household_100_to_150"].fillna(
    value=0,
    inplace=True
)
hp_test["income_household_150_over"].fillna(
    value=0,
    inplace=True
)
hp_test["income_household_six_figure"].fillna(
    value=0,
    inplace=True
)
hp_test["home_ownership"].fillna(
    value=0,
    inplace=True
)
hp_test["home_value"].fillna(
    value=0,
    inplace=True
)
hp_test["rent_median"].fillna(
    value=0,
    inplace=True
)
hp_test["rent_burden"].fillna(
    value=0,
    inplace=True
)
hp_test["self_employed"].fillna(
    value=0,
    inplace=True
)
hp_test["farmer"].fillna(
    value=0,
    inplace=True
)
hp_test["poverty"].fillna(
    value=0,
    inplace=True
)
hp_test["limited_english"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Jan-13"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Feb-13"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of May-13"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Jun-13"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Aug-13"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Sep-13"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Oct-13"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Nov-13"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Dec-13"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Jan-14"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Feb-14"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Mar-14"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Apr-14"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Jun-14"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Nov-14"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Jan-15"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Feb-15"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Mar-15"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Apr-15"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Aug-15"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Oct-15"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Nov-15"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Dec-15"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Jan-16"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Feb-16"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of May-16"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Jul-16"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Nov-16"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Dec-16"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Jan-17"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Jun-17"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Jul-17"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Sep-17"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Oct-17"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Nov-17"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Feb-18"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Mar-18"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Jun-18"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Jul-18"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Aug-18"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Sep-18"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Oct-18"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Nov-18"].fillna(
    value=0,
    inplace=True
)
hp_test["Average of Dec-18"].fillna(
    value=0,
    inplace=True
)

hp_test.columns[hp_test.isna().any()].tolist()
# Out:
# []

# %%
#One-hot encoding for columns that include String values test file.

hp_test = pd.get_dummies(hp_test, columns = ["patient_race", "payer_type", "patient_state", "Region", "Division", "patient_gender", "breast_cancer_diagnosis_code", "breast_cancer_diagnosis_desc", "metastatic_cancer_diagnosis_code", "metastatic_first_novel_treatment", "metastatic_first_novel_treatment_type"])

# %%
# Checking the results.

hp_test.head(2)
# Out:
#    patient_id  patient_zip3  patient_age   bmi  population  density  \
# 0      730681           713           55   0.0     4639.07    72.66
# 1      334212           283           60  40.0    10875.30   217.91
#
#    age_median  age_under_10  age_10_to_19  age_20s  age_30s  age_40s  age_50s  \
# 0       41.50         11.40         13.44    11.42    11.45    12.56    13.08
# 1       39.64         11.23         13.72    15.01    12.02    11.58    11.77
#
#    age_60s  age_70s  age_over_80   male  female  married  divorced  \
# 0    14.26     7.71         4.73  50.02   49.98    42.37     14.70
# 1    12.77     8.52         3.41  51.33   48.67    44.14     13.28
#
#    never_married  widowed  family_size  family_dual_income  \
# 0          34.76     8.18         3.30               38.83
# 1          34.62     7.96         3.33               42.57
#
#    income_household_median  income_household_under_5  \
# 0                 40643.61                      6.77
# ...

# %%
#Creating a new test file with only important Features

hp_test2 = hp_test[['patient_age', 'bmi', 'patient_race_0', 'patient_race_White', 'payer_type_COMMERCIAL', 'payer_type_MEDICARE ADVANTAGE', 'payer_type_MEDICAID', 'breast_cancer_diagnosis_code_C50912', 'payer_type_0', 'breast_cancer_diagnosis_code_C50919']]

# %%
#Adding the label column in the test file.

hp_test2['metastatic_diagnosis_period'] = " "
# Out:
# C:\Users\majanni1\AppData\Local\Temp\ipykernel_32520\3963181548.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hp_test2['metastatic_diagnosis_period'] = " "

# %%
hp_test2.head(5)
# Out:
#    patient_age    bmi  patient_race_0  patient_race_White  \
# 0           55   0.00            True               False
# 1           60  40.00           False               False
# 2           54  32.33            True               False
# 3           63  27.07            True               False
# 4           62   0.00           False               False
#
#    payer_type_COMMERCIAL  payer_type_MEDICARE ADVANTAGE  payer_type_MEDICAID  \
# 0                   True                          False                False
# 1                  False                          False                False
# 2                   True                          False                False
# 3                   True                          False                False
# 4                  False                          False                False
#
#    breast_cancer_diagnosis_code_C50912  payer_type_0  \
# 0                                False         False
# ...

# %%
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import matplotlib.pyplot as plt

# %%
#Creating a triangular membership function with a data series and its max, min and median

class Fuzzify(object):
    def __init__(self, data_series, Min, Max, Mid):

        
        self.data = data_series
        self.low = Min
        self.high = Max
        self.mid = Mid
        self.universe = np.arange(np.floor(self.low), np.ceil(self.high)+0.2, 0.1)
        self.trimf_low  = fuzz.trimf(self.universe, [self.low, self.low, self.mid])
        self.trimf_mid = fuzz.trimf(self.universe, [self.low, self.mid, self.high+0.1])
        self.trimf_hi  =  fuzz.trimf(self.universe, [self.mid, self.high+0.1, self.high+0.1])
        
    def get_universe(self):
        return self.universe
        
    def get_membership(self):
        
#Assigning fuzzy membership to each observation in the data series and returning a dataframe of the result
        
        
        new_df = pd.DataFrame(self.data)
        new_df['low'] = fuzz.interp_membership(self.universe, self.trimf_low, self.data)
        new_df['mid'] = fuzz.interp_membership(self.universe, self.trimf_mid, self.data)
        new_df['high'] = fuzz.interp_membership(self.universe, self.trimf_hi, self.data)
        new_df['membership'] = new_df.loc[:, ['low', 'mid', 'high']].idxmax(axis = 1)
        new_df['degree'] = new_df.loc[:, ['low', 'mid', 'high']].max(axis = 1)
        return new_df

# %%
#Fuzzifying the patient_age variable

patient_age = hp_train2.iloc[:,0]

patient_age_min = patient_age.min()
patient_age_max =  patient_age.max()                   
patient_age_mid =  np.median(np.arange(patient_age_min, patient_age_max, 0.1))            

patient_age_object = Fuzzify(patient_age, patient_age_min, patient_age_max, patient_age_mid)
fuzzified_patient_age = patient_age_object.get_membership()

fuzzified_patient_age
# Out:
#        patient_age   low   mid  high membership  degree
# 0               39  0.42  0.58  0.00        mid    0.58
# 1               55  0.00  0.98  0.02        mid    0.98
# 2               59  0.00  0.88  0.12        mid    0.88
# 3               59  0.00  0.88  0.12        mid    0.88
# 4               71  0.00  0.55  0.45        mid    0.55
# ...            ...   ...   ...   ...        ...     ...
# 13168           59  0.00  0.88  0.12        mid    0.88
# 13169           73  0.00  0.49  0.51       high    0.51
# 13170           19  0.97  0.03  0.00        low    0.97
# 13171           52  0.07  0.93  0.00        mid    0.93
# 13172           63  0.00  0.77  0.23        mid    0.77
#
# [13173 rows x 6 columns]

# %%
#Fuzzifying the bmi variable

bmi = hp_train2.iloc[:,1]
bmi_min =  bmi.min()
bmi_max =  bmi.max()                    
bmi_mid =  np.median(np.arange(bmi_min, bmi_max, 0.1))               

bmi_object = Fuzzify(bmi, bmi_min, bmi_max, bmi_mid)
fuzzified_bmi = bmi_object.get_membership()

fuzzified_bmi
# Out:
#          bmi   low   mid  high membership  degree
# 0       0.00  1.00  0.00   0.0        low    1.00
# 1      35.36  0.27  0.73   0.0        mid    0.73
# 2       0.00  1.00  0.00   0.0        low    1.00
# 3       0.00  1.00  0.00   0.0        low    1.00
# 4       0.00  1.00  0.00   0.0        low    1.00
# ...      ...   ...   ...   ...        ...     ...
# 13168   0.00  1.00  0.00   0.0        low    1.00
# 13169  30.67  0.37  0.63   0.0        mid    0.63
# 13170   0.00  1.00  0.00   0.0        low    1.00
# 13171   0.00  1.00  0.00   0.0        low    1.00
# 13172   0.00  1.00  0.00   0.0        low    1.00
#
# [13173 rows x 6 columns]

# %%
#Fuzzifying the metastatic_diagnosis_period variable

metastatic_diagnosis_period = hp_train2.iloc[:,10]
metastatic_diagnosis_period_min =  metastatic_diagnosis_period.min()
metastatic_diagnosis_period_max =  metastatic_diagnosis_period.max()                    
metastatic_diagnosis_period_mid =  np.median(np.arange(metastatic_diagnosis_period_min, metastatic_diagnosis_period_max, 0.1))              

metastatic_diagnosis_period_object = Fuzzify(metastatic_diagnosis_period, metastatic_diagnosis_period_min, metastatic_diagnosis_period_max, metastatic_diagnosis_period_mid)
fuzzified_metastatic_diagnosis_period = metastatic_diagnosis_period_object.get_membership()

fuzzified_metastatic_diagnosis_period
# Out:
#        metastatic_diagnosis_period   low   mid  high membership  degree
# 0                              191  0.00  0.95  0.05        mid    0.95
# 1                               33  0.82  0.18  0.00        low    0.82
# 2                              157  0.14  0.86  0.00        mid    0.86
# 3                              146  0.20  0.80  0.00        mid    0.80
# 4                              286  0.00  0.43  0.57       high    0.57
# ...                            ...   ...   ...   ...        ...     ...
# 13168                          106  0.42  0.58  0.00        mid    0.58
# 13169                           92  0.50  0.50  0.00        mid    0.50
# 13170                            0  1.00  0.00  0.00        low    1.00
# 13171                          330  0.00  0.19  0.81       high    0.81
# 13172                            0  1.00  0.00  0.00        low    1.00
#
# [13173 rows x 6 columns]

# %%
#Creating a summary function to extract the final rule set

def get_rule(hp_train2, *arg):
    """ return the final fuzzy rule given any number of input data columns"""
    
    rule_df = hp_train2.copy()
    rule_df['degree'] = np.ones(hp_train2.shape[0])
    for col in rule_df.columns[:-10]:
        idx = hp_train2.columns.get_loc(col)
        rule_df[col] = arg[idx]['membership']
        rule_df['degree'] *=  arg[idx]['degree']
    final_rule = rule_df.groupby(list(rule_df.columns[:-10])).max()
    final_rule = final_rule.reset_index()
    return final_rule

get_rule(hp_train2, fuzzified_patient_age, fuzzified_bmi, fuzzified_metastatic_diagnosis_period)
# Out:
#   patient_age   bmi  patient_race_0  patient_race_White  \
# 0        high   low            True                True
# 1        high   mid            True                True
# 2         low  high           False                True
# 3         low   low            True                True
# 4         low   mid            True                True
# 5         mid   low            True                True
# 6         mid   mid            True                True
#
#    payer_type_COMMERCIAL  payer_type_MEDICARE ADVANTAGE  payer_type_MEDICAID  \
# 0                   True                           True                 True
# 1                   True                           True                 True
# 2                  False                          False                 True
# 3                   True                           True                 True
# 4                   True                           True                 True
# ...

# %%
#Specifying variables

from fuzzy_expert.variable import FuzzyVariable

variables = {
    "patient_age": FuzzyVariable(
        universe_range=(0, 100),
        terms={
            "High": [(72, 0), (82, 0.33), (91, 0.66), (100, 1)],
            "Mid": [(35, 0), (44, 0.5), (54, 1), (63, 0.5), (72, 0)],
            "Low": [(0, 1), (12, 0.66), (24, 0.33), (35, 0)],
        },
    ),
    "bmi": FuzzyVariable(
        universe_range=(15, 60),
        terms={
            "High": [(40, 0), (47, 0.33), (54, 0.66), (60, 1)],
            "Mid": [(28, 0), (31, 0.5), (34, 1), (37, 0.5), (40, 0)],
            "Low": [(15, 1), (19, 0.66), (22, 0.33), (28, 0)],
        },
    ),
    #
    "metastatic_diagnosis_period": FuzzyVariable(
        universe_range=(0, 365),
        terms={
           "High": [(200, 0), (255, 0.33), (310, 0.66), (365, 1)],
            "Mid": [(100, 0), (125, 0.5), (150, 1), (175, 0.5), (200, 0)],
            "Low": [(0, 0), (33, 0.33), (66, 0.66), (100, 0)],
        },
    ),
}

plt.figure(figsize=(10, 2.5))
variables["patient_age"].plot()

# %%
#Specifying rules

from fuzzy_expert.rule import FuzzyRule

rules = [
    FuzzyRule(
        premise=[
            ("patient_age", "High"),
            ("AND", "bmi", "Low"),
        ],
        consequence=[("metastatic_diagnosis_period", "High")],
    ),
    FuzzyRule(
        premise=[
            ("patient_age", "High"),
            ("AND", "bmi", "Mid"),
        ],
        consequence=[("metastatic_diagnosis_period", "High")],
    ),
     FuzzyRule(
        premise=[
            ("patient_age", "Low"),
            ("AND", "bmi", "High"),
        ],
        consequence=[("metastatic_diagnosis_period", "Mid")],
    ),
     FuzzyRule(
        premise=[
            ("patient_age", "Low"),
            ("AND", "bmi", "Low"),
        ],
        consequence=[("metastatic_diagnosis_period", "High")],
    ),
      FuzzyRule(
        premise=[
            ("patient_age", "Low"),
            ("AND", "bmi", "Mid"),
        ],
        consequence=[("metastatic_diagnosis_period", "High")],
    ),
        FuzzyRule(
        premise=[
            ("patient_age", "Mid"),
            ("AND", "bmi", "Low"),
        ],
        consequence=[("metastatic_diagnosis_period", "High")],
    ),
            FuzzyRule(
        premise=[
            ("patient_age", "Mid"),
            ("AND", "bmi", "Mid"),
        ],
        consequence=[("metastatic_diagnosis_period", "High")],
    )
]

print(rules[0])
print()
print(rules[1])
# Out:
# IF  patient_age IS High
#     AND bmi IS Low
# THEN
#     metastatic_diagnosis_period IS High
# CF = 1.00
# Threshold-CF = 0.00
#
#
# IF  patient_age IS High
#     AND bmi IS Mid
# THEN
#     metastatic_diagnosis_period IS High
# CF = 1.00
# Threshold-CF = 0.00

# %%
#Evaluating crisp values from the test data

from fuzzy_expert.inference import DecompositionalInference

model = DecompositionalInference(
    and_operator="min",
    or_operator="max",
    implication_operator="Rc",
    composition_operator="max-min",
    production_link="max",
    defuzzification_operator="cog",
)

model(
    variables=variables,
    rules=rules,
    patient_age=60,
    bmi=40,
)
# Out:
# ({'metastatic_diagnosis_period': 182.5}, 1.0)
